# %%
import tensorflow as tf


x = tf.constant(35, name='x');
y = tf.Variable(x + 5, name='y');

print(y)
# Out:
# D:\libs\anaconda\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <tf.Variable 'y:0' shape=() dtype=int32_ref>

# %%
model = tf.global_variables_initializer()

with tf.Session() as session:
    session.run(model)
    print(session.run(y))
# Out:
# 40

# %%
x = tf.constant([35,45,55],name='x');
y = tf.Variable(x+5,name = 'y');

model = tf.global_variables_initializer()

with tf.Session() as session:
    session.run(model)
    print(session.run(y))
# Out:
# [40 50 60]

# %%
import numpy as np

data = np.random.randint(1000, size=10000);
#sdata = tf.constant(data,name='sdata');
y = tf.Variable(data-1000,name='y')

model = tf.global_variables_initializer()

with tf.Session() as session:
    session.run(model)
    print(session.run(y))
# Out:
# [-467 -402 -847 ... -606 -346  -99]

# %%
x = tf.constant(35, name='x')
print(x)
y = tf.Variable(x + 5, name='y')

with tf.Session() as session:
    merged = tf.summary.merge_all()
    writer = tf.summary.FileWriter("d://datas", session.graph)
    model =  tf.global_variables_initializer()
    session.run(model)
    print(session.run(y))
# Out:
# Tensor("x_5:0", shape=(), dtype=int32)
# 40

# %%
a = tf.add(1, 2, name="Add_these_numbers")
b = tf.multiply(a, 3)
c = tf.add(4, 5, name="And_These_ones")
d = tf.multiply(c, 6, name="Multiply_these_numbers")
e = tf.multiply(4, 5, name="B_add")
f = tf.div(c, 6, name="B_mul")
g = tf.add(b, d)
h = tf.multiply(g, f)

with tf.Session() as sess:
    writer = tf.summary.FileWriter("d://datas", sess.graph)
    print(sess.run(h))
    writer.close()
# Out:
# 63

# %%
a = tf.constant([[1, 2, 3], [4, 5, 6]], name='a')
b = tf.constant([[1, 2, 3], [4, 5, 6]], name='b')
add_op = a + b

with tf.Session() as session:
    print(session.run(add_op))
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
a = tf.constant([[1, 2, 3], [4, 5, 6]], name='a')
b = tf.constant([100, 101, 102], name='b')



add_op = a + b

with tf.Session() as session:
    print(session.run(add_op))
# Out:
# [[101 103 105]
#  [104 106 108]]

# %%
a = tf.constant([[1, 2, 3], [4, 5, 6]], name='a')
b = tf.constant([100, 101,], name='b')

print(a.shape)
    #TensorShape([Dimension(2), Dimension(3)])
b.shape
    #TensorShape([Dimension(2), Dimension(1)])

#add_op = a + b

#with tf.Session() as session:
    #print(session.run(add_op))
# Out:
# TensorShape([Dimension(2)])

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
# First, load the image

filename = 'D://datas' + "/pic.jpg"

# Load the image
image = mpimg.imread(filename)

# Print out its shape
print(image.shape)

#plt.imshow(image)
plt.show()
# Out:
# (1080, 1920, 3)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
# First, load the image again

filename = 'D://datas' + "/pic.jpg"
image = mpimg.imread(filename)
height, width, depth = image.shape

# Create a TensorFlow Variable
x = tf.Variable(image, name='x')

model = tf.global_variables_initializer()

with tf.Session() as session:
    x = tf.reverse_sequence(x, [width] * height, 1, batch_dim=0)
    session.run(model)
    result = session.run(x)

print(result.shape)
plt.imshow(result)
plt.show()
# Out:
# (1080, 1920, 3)
